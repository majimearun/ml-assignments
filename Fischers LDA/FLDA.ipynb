# %%
import numpy as np
import pandas as pd
from FischersLinearDiscriminant import FischersLinearDiscriminant
import sys
sys.path.append("..")
from preprocessor import Preprocessor

# %%
dataset = pd.read_csv("../dataset.csv")

# %%
preprocessor = Preprocessor(dataset, "diagnosis")
preprocessor.preprocess()
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0   -0.235018          1     1.094879     -2.074763        1.267062
# 1   -0.235016          1     1.826349     -0.353230        1.682331
# 2    0.429419          1     1.576855      0.457451        1.563095
# 3    0.429796          1    -0.767816      0.254781       -0.592194
# 4    0.429877          1     1.746964     -1.152264        1.772786
# ..        ...        ...          ...           ...             ...
# 564 -0.234348          1     2.107029      0.723019        2.056485
# 565 -0.234346          1     1.701602      2.088132        1.612434
# 566 -0.234344          1     0.700793      2.048530        0.670883
# 567 -0.234342          1     1.834854      2.339723        1.978365
# 568 -0.240985         -1    -1.805481      1.223871       -1.811689
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     0.981944         1.566682          3.267937        2.640012
# 1     1.904450        -0.826446         -0.489576       -0.027425
# 2     1.555317         0.941027          1.045082        1.355088
# 3    -0.763436         3.280121          3.386918        1.905591
# 4     1.822134         0.279824          0.533277        1.362595
# ..         ...              ...               ...             ...
# 564   2.338738         1.040563          0.214108        1.936869
# 565   1.719949         0.102082         -0.021965        0.686978
# 566   0.576326        -0.839955         -0.042739        0.042764
# 567   1.731303         1.524023          3.256606        3.281848
# 568  -1.345609        -3.109373         -1.150956       -1.114668
#
#      concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0               2.524862  ...      1.879756      -1.359868         2.294663
# 1               0.544898  ...      1.799228      -0.370226         1.528487
# 2               2.030708  ...      1.506022      -0.025153         1.341397
# 3               1.446473  ...     -0.282118       0.132734        -0.251239
# 4               1.423309  ...      1.293345      -1.467297         1.332488
# ..                   ...  ...           ...            ...              ...
# 564             2.313817  ...      1.894210       0.116457         1.745273
# 565             1.258848  ...      1.530800       2.045284         1.415639
# 566             0.103504  ...      0.558267       1.373043         0.575221
# 567             2.650975  ...      1.954090       2.235725         2.294663
# 568            -1.261083  ...     -1.408275       0.762655        -1.430497
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      1.992752          1.299133           2.601250         2.095524
# 1      1.882378         -0.376439          -0.434738        -0.151893
# 2      1.449643          0.522436           1.073115         0.845897
# 3     -0.549875          3.376144           3.873322         1.976057
# 4      1.214880          0.216993          -0.318115         0.605051
# ..          ...               ...                ...              ...
# 564    2.006768          0.374078          -0.278185         0.656183
# 565    1.488186         -0.690608          -0.399244         0.229924
# 566    0.424743         -0.808422           0.343591         0.319764
# 567    1.645863          1.421310           3.884731         3.179331
# 568   -1.073888         -1.853036          -1.209010        -1.306424
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                2.284458        2.736119                 1.924898
# 1                1.080081       -0.246999                 0.274810
# 2                1.944684        1.143833                 0.195287
# 3                2.164627        6.019000                 4.912506
# 4                0.723621       -0.869087                -0.401130
# ..                    ...             ...                      ...
# 564              1.620079       -1.359021                -0.712040
# 565              0.728172       -0.533869                -0.976010
# 566              0.409634       -1.104384                -0.322712
# 567              2.278391        1.907744                 2.206539
# 568             -1.741257       -0.051993                -0.754010
#
# [563 rows x 32 columns]

# %%
accuracies = []
precisions = []
recalls = []

# %%
for _ in range(100):

    splits = preprocessor.get_folds(100)

    train = pd.concat(splits[:67])
    test = pd.concat(splits[67:])

    X_train = train.drop(columns=["diagnosis"]).to_numpy()
    y_train = train["diagnosis"].to_numpy()
    X_test = test.drop(columns=["diagnosis"]).to_numpy()
    y_test = test["diagnosis"].to_numpy()

    flda = FischersLinearDiscriminant()
    flda.fit(X_train, y_train)
    accuracy, precision, recall = flda.score(X_test, y_test)
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)

# %%
print('----Results----')
print(f"Accuracy mean: {np.mean(accuracies).round(4)*100}%, stdev: {np.std(accuracies).round(4)*100}%")
print(f"Precision mean: {np.mean(precisions).round(4)*100}%, stdev: {np.std(precisions).round(4)*100}%")
print(f"Recall mean: {np.mean(recalls).round(4)*100}%, stdev: {np.std(recalls).round(4)*100}%")
# Out:
# ----Results----
# Accuracy mean: 96.22%, stdev: 1.35%
# Precision mean: 97.92%, stdev: 1.66%
# Recall mean: 92.07%, stdev: 3.19%
