# %%
import numpy as np
import pandas as pd
from FischersLinearDiscriminant import FischersLinearDiscriminant
import sys
sys.path.append("..")
from preprocessor import Preprocessor

# %%
dataset = pd.read_csv("../dataset.csv")
dataset.drop(columns = ["id"], inplace=True)

# %%
preprocessor = Preprocessor(dataset, "diagnosis", )
preprocessor.preprocess()
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1     1.094879     -2.074763        1.267062   0.981944
# 1            1     1.826349     -0.353230        1.682331   1.904450
# 2            1     1.576855      0.457451        1.563095   1.555317
# 3            1    -0.767816      0.254781       -0.592194  -0.763436
# 4            1     1.746964     -1.152264        1.772786   1.822134
# ..         ...          ...           ...             ...        ...
# 564          1     2.107029      0.723019        2.056485   2.338738
# 565          1     1.701602      2.088132        1.612434   1.719949
# 566          1     0.700793      2.048530        0.670883   0.576326
# 567          1     1.834854      2.339723        1.978365   1.731303
# 568         -1    -1.805481      1.223871       -1.811689  -1.345609
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           1.566682          3.267937        2.640012             2.524862
# 1          -0.826446         -0.489576       -0.027425             0.544898
# 2           0.941027          1.045082        1.355088             2.030708
# 3           3.280121          3.386918        1.905591             1.446473
# 4           0.279824          0.533277        1.362595             1.423309
# ..               ...               ...             ...                  ...
# 564         1.040563          0.214108        1.936869             2.313817
# 565         0.102082         -0.021965        0.686978             1.258848
# 566        -0.839955         -0.042739        0.042764             0.103504
# 567         1.524023          3.256606        3.281848             2.650975
# 568        -3.109373         -1.150956       -1.114668            -1.261083
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         2.210508  ...      1.879756      -1.359868         2.294663
# 1        -0.000317  ...      1.799228      -0.370226         1.528487
# 2         0.935732  ...      1.506022      -0.025153         1.341397
# 3         2.858822  ...     -0.282118       0.132734        -0.251239
# 4        -0.011244  ...      1.293345      -1.467297         1.332488
# ..             ...  ...           ...            ...              ...
# 564      -0.313548  ...      1.894210       0.116457         1.745273
# 565      -0.218850  ...      1.530800       2.045284         1.415639
# 566      -0.808889  ...      0.558267       1.373043         0.575221
# 567       2.130379  ...      1.954090       2.235725         2.294663
# 568      -0.819816  ...     -1.408275       0.762655        -1.430497
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      1.992752          1.299133           2.601250         2.095524
# 1      1.882378         -0.376439          -0.434738        -0.151893
# 2      1.449643          0.522436           1.073115         0.845897
# 3     -0.549875          3.376144           3.873322         1.976057
# 4      1.214880          0.216993          -0.318115         0.605051
# ..          ...               ...                ...              ...
# 564    2.006768          0.374078          -0.278185         0.656183
# 565    1.488186         -0.690608          -0.399244         0.229924
# 566    0.424743         -0.808422           0.343591         0.319764
# 567    1.645863          1.421310           3.884731         3.179331
# 568   -1.073888         -1.853036          -1.209010        -1.306424
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                2.284458        2.736119                 1.924898
# 1                1.080081       -0.246999                 0.274810
# 2                1.944684        1.143833                 0.195287
# 3                2.164627        6.019000                 4.912506
# 4                0.723621       -0.869087                -0.401130
# ..                    ...             ...                      ...
# 564              1.620079       -1.359021                -0.712040
# 565              0.728172       -0.533869                -0.976010
# 566              0.409634       -1.104384                -0.322712
# 567              2.278391        1.907744                 2.206539
# 568             -1.741257       -0.051993                -0.754010
#
# [563 rows x 31 columns]

# %%
accuracies: list[float] = []
precisions: list[tuple[float, float]] = []
recalls: list[tuple[float, float]] = []

# %%
for _ in range(10):

    splits = preprocessor.get_folds(100)

    train = pd.concat(splits[:67])
    test = pd.concat(splits[67:])

    X_train = train.drop(columns=["diagnosis"]).to_numpy()
    y_train = train["diagnosis"].to_numpy()
    X_test = test.drop(columns=["diagnosis"]).to_numpy()
    y_test = test["diagnosis"].to_numpy()

    fldm1 = FischersLinearDiscriminant()
    fldm1.fit(X_train, y_train)
    tp, tn, fp, fn = fldm1.score(X_test, y_test)
    accuracies.append((tp+tn)/(tp+tn+fp+fn))
    precisions.append((tp/(tp+fp), tn/(tn+fn)))
    recalls.append((tp/(tp+fn), tn/(tn+fp)))

# %%
print('--------Results--------')
print(f"Accuracy mean: {np.mean(accuracies).round(4)*100}%, stdev: {np.std(accuracies).round(4)*100}%")

print("----Class 1----")
print(f"Precision mean: {np.mean([precision[0] for precision in precisions]).round(4)*100}%, stdev: {np.std([precision[0] for precision in precisions]).round(4)*100}%")
print(f"Recall mean: {np.mean([recall[0] for recall in recalls]).round(4)*100}%, stdev: {np.std([recall[0] for recall in recalls]).round(4)*100}%")

print("----Class -1----")
print(f"Precision mean: {np.mean([precision[1] for precision in precisions]).round(4)*100}%, stdev: {np.std([precision[1] for precision in precisions]).round(4)*100}%")
print(f"Recall mean: {np.mean([recall[1] for recall in recalls]).round(4)*100}%, stdev: {np.std([recall[1] for recall in recalls]).round(4)*100}%")
# Out:
# --------Results--------
# Accuracy mean: 96.67%, stdev: 1.1900000000000002%
# ----Class 1----
# Precision mean: 97.71%, stdev: 1.7399999999999998%
# Recall mean: 93.35%, stdev: 2.32%
# ----Class -1----
# Precision mean: 95.97%, stdev: 1.83%
# Recall mean: 98.76%, stdev: 0.83%

# %%
shuffled_dataset = dataset.sample(frac=1, axis=1)

# %%
dataset.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
shuffled_dataset.columns
# Out:
# Index(['smoothness_worst', 'perimeter_worst', 'fractal_dimension_worst',
#        'area_worst', 'perimeter_mean', 'smoothness_mean', 'perimeter_se',
#        'compactness_mean', 'concave points_se', 'concave points_worst',
#        'smoothness_se', 'concavity_worst', 'fractal_dimension_se', 'diagnosis',
#        'texture_se', 'concavity_mean', 'symmetry_mean', 'concavity_se',
#        'compactness_worst', 'symmetry_se', 'fractal_dimension_mean',
#        'texture_worst', 'area_se', 'radius_se', 'texture_mean',
#        'symmetry_worst', 'radius_worst', 'radius_mean', 'concave points_mean',
#        'area_mean', 'compactness_se'],
#       dtype='object')

# %%
preprocessor = Preprocessor(shuffled_dataset, "diagnosis")
preprocessor.preprocess()
# Out:
#      smoothness_worst  perimeter_worst  fractal_dimension_worst  area_worst  \
# 0            1.299133         2.294663                 1.924898    1.992752
# 1           -0.376439         1.528487                 0.274810    1.882378
# 2            0.522436         1.341397                 0.195287    1.449643
# 3            3.376144        -0.251239                 4.912506   -0.549875
# 4            0.216993         1.332488                -0.401130    1.214880
# ..                ...              ...                      ...         ...
# 564          0.374078         1.745273                -0.712040    2.006768
# 565         -0.690608         1.415639                -0.976010    1.488186
# 566         -0.808422         0.575221                -0.322712    0.424743
# 567          1.421310         2.294663                 2.206539    1.645863
# 568         -1.853036        -1.430497                -0.754010   -1.073888
#
#      perimeter_mean  smoothness_mean  perimeter_se  compactness_mean  \
# 0          1.267062         1.566682      2.822172          3.267937
# 1          1.682331        -0.826446      0.261722         -0.489576
# 2          1.563095         0.941027      0.847207          1.045082
# 3         -0.592194         3.280121      0.284905          3.386918
# 4          1.772786         0.279824      1.267948          0.533277
# ..              ...              ...           ...               ...
# 564        2.056485         1.040563      2.370357          0.214108
# 565        1.612434         0.102082      1.152035         -0.021965
# 566        0.670883        -0.839955      0.275040         -0.042739
# 567        1.978365         1.524023      1.432693          3.256606
# 568       -1.811689        -3.109373     -0.157539         -1.150956
#
#      concave points_se  concave points_worst  ...  texture_worst   area_se  \
# 0             0.665918              2.284458  ...      -1.359868  2.477199
# 1             0.264316              1.080081  ...      -0.370226  0.738863
# 2             1.431726              1.944684  ...      -0.025153  1.176077
# 3             1.121175              2.164627  ...       0.132734 -0.287878
# 4             1.150442              0.723621  ...      -1.467297  1.185062
# ..                 ...                   ...  ...            ...       ...
# 564           2.075590              1.620079  ...       0.116457  2.593351
# 565           0.813876              0.728172  ...       2.045284  1.285873
# 566           0.617140              0.409634  ...       1.373043  0.179360
# 567           0.791114              2.278391  ...       2.235725  1.004917
# 568          -1.914416             -1.741257  ...       0.762655 -0.464955
#
#      radius_se  texture_mean  symmetry_worst  radius_worst  radius_mean  \
# 0     2.482684     -2.074763        2.736119      1.879756     1.094879
# 1     0.497887     -0.353230       -0.246999      1.799228     1.826349
# 2     1.225226      0.457451        1.143833      1.506022     1.576855
# 3     0.325500      0.254781        6.019000     -0.282118    -0.767816
# 4     1.266974     -1.152264       -0.869087      1.293345     1.746964
# ..         ...           ...             ...           ...          ...
# 564   2.774196      0.723019       -1.359021      1.894210     2.107029
# 565   1.296844      2.088132       -0.533869      1.530800     1.701602
# 566   0.184423      2.048530       -1.104384      0.558267     0.700793
# 567   1.154688      2.339723        1.907744      1.954090     1.834854
# 568  -0.070020      1.223871       -0.051993     -1.408275    -1.805481
#
#      concave points_mean  area_mean  compactness_se
# 0               2.524862   0.981944        1.308033
# 1               0.544898   1.904450       -0.693745
# 2               2.030708   1.555317        0.808145
# 3               1.446473  -0.763436        2.729763
# 4               1.423309   1.822134       -0.051907
# ..                   ...        ...             ...
# 564             2.313817   2.338738        0.187460
# 565             1.258848   1.719949       -0.073060
# 566             0.103504   0.576326        0.655061
# 567             2.650975   1.731303        2.006095
# 568            -1.261083  -1.345609       -1.162459
#
# [563 rows x 31 columns]

# %%
accuracies: list[float] = []
precisions: list[tuple[float, float]] = []
recalls: list[tuple[float, float]] = []

# %%
for _ in range(10):

    splits = preprocessor.get_folds(100)

    train = pd.concat(splits[:67])
    test = pd.concat(splits[67:])

    X_train = train.drop(columns=["diagnosis"]).to_numpy()
    y_train = train["diagnosis"].to_numpy()
    X_test = test.drop(columns=["diagnosis"]).to_numpy()
    y_test = test["diagnosis"].to_numpy()

    fldm2 = FischersLinearDiscriminant()
    fldm2.fit(X_train, y_train)
    tp, tn, fp, fn = fldm2.score(X_test, y_test)
    accuracies.append((tp+tn)/(tp+tn+fp+fn))
    precisions.append((tp/(tp+fp), tn/(tn+fn)))
    recalls.append((tp/(tp+fn), tn/(tn+fp)))

# %%
print('--------Results--------')
print(f"Accuracy mean: {np.mean(accuracies).round(4)*100}%, stdev: {np.std(accuracies).round(4)*100}%")

print("----Class 1----")
print(f"Precision mean: {np.mean([precision[0] for precision in precisions]).round(4)*100}%, stdev: {np.std([precision[0] for precision in precisions]).round(4)*100}%")
print(f"Recall mean: {np.mean([recall[0] for recall in recalls]).round(4)*100}%, stdev: {np.std([recall[0] for recall in recalls]).round(4)*100}%")

print("----Class -1----")
print(f"Precision mean: {np.mean([precision[1] for precision in precisions]).round(4)*100}%, stdev: {np.std([precision[1] for precision in precisions]).round(4)*100}%")
print(f"Recall mean: {np.mean([recall[1] for recall in recalls]).round(4)*100}%, stdev: {np.std([recall[1] for recall in recalls]).round(4)*100}%")
# Out:
# --------Results--------
# Accuracy mean: 97.21%, stdev: 0.8200000000000001%
# ----Class 1----
# Precision mean: 97.92%, stdev: 1.48%
# Recall mean: 94.47%, stdev: 2.08%
# ----Class -1----
# Precision mean: 96.78999999999999%, stdev: 1.41%
# Recall mean: 98.87%, stdev: 0.8200000000000001%
